# %%
import numpy as np 
import matplotlib.pyplot as plt 
import pandas as pd 
from sklearn.decomposition import PCA 
import matplotlib.image as mplib

# %%
# step1 : read the image
# step2 : reshape image to PCA understandable format
# step3 : PCA with n-components
# step4 : Inverse transform to recreate the original dimension.
# step5 : Display compressed image.

# %%
# step1 : read the image.
img = mplib.imread('./static/images/pythonflaskcourse.jpg')
img
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
imgplot = plt.imshow(img)

# %%
# step2 : reshape image to PCA understandable format 

(height , width , s)  = img.shape
print("Size of original image" , img.size)
print("height " , height ,"width = " ,width , s)
# Out:
# Size of original image 5712000
# height  1190 width =  1600 3

# %%
img_re = np.reshape(img , (1190 , 1600 * 3))
print("Reshaped image : " , img_re.shape)
# Out:
# Reshaped image :  (1190, 4800)

# %%
imgplot =  plt.imshow(img_re)
